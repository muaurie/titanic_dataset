# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
#from mean_median_mode.ipynb import compute_mean
#from mean_median_mode.ipynb import compute_median
#from mean_median_mode.ipynb import standard_deviation

#data = np.array([1, 3, 5, 2, 3, 7, 8, 4, 10, 0, 6, 7, 3, 0, 3, 0, 5, 7, 10, 1, 4, 9, 3])
#another example of the data
#df = pd.DataFrame([[10, 20, 30, 40], [7, 14, 21, 28], [55, 15, 8, 12],
#                  [15, 14, 1, 8], [7, 1, 1, 8], [5, 4, 9, 2]],
#                  columns=['Apple', 'Orange', 'Banana', 'Pear'],
#                 index=['Basket1', 'Basket2', 'Basket3', 'Basket4',
#                        'Basket5', 'Basket6'])
df = pd.read_csv('titanic.csv')
#df['Age'].mean()
#df['Age'].mode()
#df['Age'].median()
df.isnull().sum()
df.describe()

# Age Histogram
plt.hist(df.Age)
plt.axvline(df.Age.mean(), color='k', linestyle='dashed', linewidth=1)
plt.title('Ages of Passengers on Titanic')
plt.ylabel('Count')
plt.xlabel('Age (in Years)')
# Age
plt.axvline(df.Age.mean()+df.Age.std(), color='k', linestyle='dashed', linewidth=1)
plt.axvline(df.Age.mean()-df.Age.std(), color='k', linestyle='dashed', linewidth=1)

# Fare Histogram

plt.hist(df.Fare)
plt.axvline(df.Fare.mean(), color='k', linestyle='dashed', linewidth=1)
plt.title('Fares of Passengers on Titanic')
plt.ylabel('Count')
plt.xlabel('Fare (in Dollars)')

# Fare
plt.axvline(df.Fare.mean()+df.Fare.std(), color='k', linestyle='dashed', linewidth=1)
plt.axvline(df.Fare.mean()-df.Fare.std(), color='k', linestyle='dashed', linewidth=1)

# use existing mode
mode = stats.mode(data)
print(mode)

    
#compute_mean(data)
#np.mean(data)
#np.median(data)

#df.var()

#print("\n----------- Calculate Mean -----------\n")
#print(df.mean())

#print("\n----------- Calculate Median -----------\n")
#print(df.median())

#print("\n----------- Calculate Mode -----------\n")
#print(df.mode())
# Out:
# ModeResult(mode=3, count=5)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 64
#      47 print(mode)
#      50 #compute_mean(data)
#      51 #np.mean(data)
#      52 #np.median(data)
#    (...)
#      62 #print("\n----------- Calculate Mode -----------\n")
#      63 #print(df.mode())
# ---> 64 print("Standard Deviation:", standard_deviation(low_variance))
#      65 print("Standard Deviation:", np.std(low_variance))
#      67 print("Standard Deviation:", standard_deviation(high_variance))
#
# NameError: name 'low_variance' is not defined
